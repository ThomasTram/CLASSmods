# %%
from scipy.fftpack import ifftn
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
N = 30
Box = 1.0
R = numpy.random.normal(loc=0.0, scale=1.0, size=(N,N))
xf1 = np.zeros((N,N),dtype=complex)
xf2 = np.zeros((N,N),dtype=complex)

for kx in range(N):
    kxm = (N - kx)%N
    for ky in range(N/2+1):
        kym = (N-ky)%N
        if (kx==0) and (ky==0):
            xf1[0,0] = 0.
            continue
        if (ky==kym) and (kx>N/2):
            continue
            
        if (kx < N/2)
            xkvec = kx*2*Pi/Box
        else
            xkvec = -(N - kx)*2*Pi/Box

            if(k < Nmesh / 2)
              kvec[2] = k * 2 * PI / Box;
            else
              kvec[2] = -(Nmesh - k) * 2 * PI / Box;
        k1 = sqrt(kx*kx+ky*ky)
        k2 = 
        
        if kx==kxm and ky==kym:
            xf1[kx,ky] = RR[kx,ky]
        else:
            xf1[kx, ky] = RR[kx,ky]+1j*RR[kxm,kym]
            xf1[kxm, kym] = RR[kx,ky]-1j*RR[kxm,kym]

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, sharex='col', sharey='row')

Z1 = ifftn(xf1)
Z2 = ifftn(xf2)

ax1.imshow(xf1, cmap=cm.Reds)
ax2.imshow(xf2, cmap=cm.Reds)

rZ1 = np.real(Z1)
rZ2 = np.real(Z2)
ax3.imshow(rZ1, cmap=cm.binary)
ax4.imshow(rZ2, cmap=cm.binary)

[DX1, DY1] = np.gradient(rZ1)
[DX2, DY2] = np.gradient(rZ2)

Q1 = ax5.quiver(DX1, DY1)

Q2 = ax6.quiver(DX2, DY2)

show()

# %%
Q1 = quiver(DX1, DY1)

# %%
Q2 = quiver(DX2, DY2)
